# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from spectral import *
import numpy as np
import PIL
import sympy as sp
from mpmath import *
import matplotlib
import matplotlib.pyplot as plt

# %%
import numpy

# %%
#img = aviris.open('f970619t01p02_r02_sc05.a.rfl','f970619t01p02_r02.a.spc')
img = aviris.open('hawaii_sc01.raw')

# %%
view = imshow(img, (1,2,100))

# %%
img
# Out:
# 	Data Source:   './hawaii_sc01.raw'
# 	# Rows:            512
# 	# Samples:         614
# 	# Bands:           224
# 	Interleave:        BIP
# 	Quantization:  16 bits
# 	Data format:     int16

# %%
arr = img.load()

# %%
block = []
for i in range(224):
    data = arr[:40,:40,i].astype(np.float32)*10000 
    block.append(data)

# %%
corr = []
for i in range(223):
    cor = np.corrcoef(block[i].reshape(-1), block[i+1].reshape(-1))[0][1]
    corr.append(cor)
print "process complete"
# Out:
# process complete

# %%
plt.figure(1)
plt.plot(range(0,223),corr, 'k')
plt.xlabel('Band Number')
plt.ylabel('Correlation Coefficient')
plt.title('Correlation Coefficient vs Band Number before Sort')
plt.show()
#Correlation ended

# %%
def msort4(x):
    result = []
    if len(x) < 20:
        return sorted(x)
    mid = int(len(x)/2)
    y = msort4(x[:mid])
    z = msort4(x[mid:])
    i = 0
    j = 0
    while i < len(y) and j < len(z):
            if y[i] > z[j]:
                result.append(z[j])
                j += 1
            else:
                result.append(y[i])
                i += 1
    result += y[i:]
    result += z[j:]
    return result

# %%
res123 = msort4(corr)

# %%
plt.figure(12)
plt.plot(range(0,223),res123, 'k')
plt.xlabel('Band')
plt.ylabel('Correlation')
plt.title('Correlation vs band')
plt.show()

# %%
indexi = []
for i in range(len(corr)):
    ind = corr.index(res123[i])
    indexi.append(ind)
print 'process complete'
# Out:
# process complete

# %%
len(indexi)
# Out:
# 223

# %%
rblock = []
for i in range(len(indexi)):
    rblock.append(block[indexi[i]])
rblock.append(block[223])
print 'process complete'
# Out:
# process complete

# %%
corrmerge = []
for i in range(223):
    cor1 = np.corrcoef(rblock[i].reshape(-1), rblock[i+1].reshape(-1))[0][1]
    corrmerge.append(cor1)
print corrmerge
# Out:
# [0.03088725368080791, 0.053827638542003037, 0.036710368974462934, 0.099795508481439685, 0.012207449941594662, 0.11942699474272997, -0.00092780465552116671, 0.14846488211139441, 0.21842862236574384, 0.18887757254056933, 0.25433021620003732, 0.22971703637555985, 0.2571989119030122, 0.066240779251266868, 0.024381172714918263, 0.28373694720239295, 0.28333060551954725, 0.30425546030804246, 0.35142240538143343, 0.36295109440322454, 0.36915449124001842, 0.33412017144197115, 0.36375621469168729, 0.38185791825011534, 0.37443017150333963, 0.38030590232523098, 0.4032838018940475, -0.028577558041549118, 0.084197532072328038, 0.14676523675410444, 0.59695064255320041, 0.4851043123757055, 0.57162906320948526, 0.52150137019881138, 0.33541455035637213, 0.4093671397467617, 0.70727052002115287, 0.48194421251578162, 0.57214715948936079, 0.59612368311791186, 0.58405371840874376, 0.64708834109951485, 0.42960963346363457, 0.72568332496164545, 0.88503950712924095, 0.8041953792528681, 0.91697759659972955, 0.81332749379186087, 0.84891248819907361, 0.7076581443667308, 0.87038130584041296, 0.90799041683326676, 0.81301623624630903, 0.76597561592804542, 0.93619600042589246, 0.92503851662230152, 0.93952114634155603, 0.55946857637326608, 0.56636170227264016, 0.83982223487023799, 0.72899603854228301, 0.91538217948612877, 0.54474597548887294, 0.56640945333214721, 0.74186502501126028, 0.67030153641329615, 0.96172337639811367, 0.73190531826349503, 0.82184629845232626, 0.61597426892954621, 0.7002426442776537, 0.96870989936011775, 0.85536223407619383, 0.45906539799808338, 0.6844812094327537, 0.60722850605090195, 0.70832562950734768, 0.93244028182928074, 0.84969884410561347, 0.96812849750061591, 0.89436663833215702, 0.45901897836151145, 0.98853719442606114, 0.47453355158079469, 0.86146462451817041, 0.74090083859087863, 0.74513644360998466, 0.68289344893534643, 0.31029646440841885, 0.98127074507575607, 0.87589223264366001, 0.8887414071430022, 0.9661399067546772, 0.98784299645598606, 0.49988395022497717, 0.86103277361792196, 0.46883819985830244, 0.86186761869593986, 0.88230638955532925, 0.97724879048752622, 0.97929080711294525, 0.88465992665813742, 0.88035468993915822, 0.85956187668625106, 0.98495200306755293, 0.97318403378438645, 0.88718476230351595, 0.67288674426750794, 0.60949900410953994, 0.57930720650817902, 0.98122720742432801, 0.98519477837759295, 0.98160741848498123, 0.96803149783959996, 0.96162505280489874, 0.8034712458494796, 0.82710114956160108, 0.99216385169455878, 0.9884793627758971, 0.99118740697886787, 0.80949191397752907, 0.82023197950579707, 0.69851719782863997, 0.83939679114053867, 0.94782557940986456, 0.66743799704655937, 0.65945003120661683, 0.67423847238430024, 0.67164569524033813, 0.83667017467877514, 0.40190240879313388, 0.94862997835464258, 0.99201887610431594, 0.74374120662679444, 0.98982634645140655, 0.76878151159945707, 0.74405525568280373, 0.99044246771608146, 0.993164558174086, 0.77094939317799394, 0.72584969951279599, 0.99043533412918594, 0.99354723003514933, 0.99344604175782036, 0.93910164952848108, 0.88298883055268329, 0.95606074244345041, 0.74867187826416914, 0.8582089930620268, 0.99479642372470634, 0.37807859894182211, 0.30615386282967938, 0.90944234880399522, 0.74869636060080913, 0.99560118557396071, 0.9957372625421782, 0.70278618421130634, 0.70155837100470309, 0.98946947520096118, 0.98754512182746146, 0.84699286184674416, 0.45493127778420078, 0.71394433377329147, 0.99565046954478376, 0.99698691649472093, 0.99230184268216926, 0.99749983828863598, 0.67355092251239868, 0.698573711784514, 0.99765304314636705, 0.9908077192256779, 0.99169619491354055, 0.99395773234293405, 0.7421119799260133, 0.76030939012895626, 0.74494975276983133, 0.74162913652843843, 0.74289526034723341, 0.98268605871846249, 0.98897590067454755, 0.83073701347656803, 0.99791980894601784, 0.76831805240488771, 0.77236059354268383, 0.75153250398105942, 0.75537021403759652, 0.99807373955863676, 0.99678982969897612, 0.75397193940745355, 0.76457851069431026, 0.75801886809846 ...

# %%
plt.figure(14)
plt.plot(range(0,223),corrmerge, 'k')
plt.xlabel('Band Number')
plt.ylabel('Correlation Coefficient')
plt.title('Correlation Coefficient vs Band Number after MergeSort')
plt.show()

# %%
from sklearn.preprocessing import normalize

# %%
rblockn = []
for q in range(len(rblock)):
    xc = rblock[q]
    xv = normalize(xc)
    rblockn.append(xv)
print('Process Complete')
# Out:
# Process Complete

# %%
def snake(arr):
    a = arr
    xx = []
    yx = 1
    for i in range(5):
        zz = []
        for j in range(5):
            x = a[i][j]
            zz.append(x)
        if yx==-1:
            zz.reverse
        xx.extend(zz)
        yx = yx * -1
        del zz
    return xx

# %%
#imagescanning
finlist = []
for i in range(224):
    rblockyo = rblockn[i]
    xx = rblockyo[:5,:5]
    yy = snake(xx)
    finlist = finlist + yy

# %%
len(finlist)
# Out:
# 5600

# %%
plt.figure(15)
plt.plot(range(5000,5500),finlist[5000:5500], 'k')
plt.xlabel('Pixel Number')
plt.ylabel('Pixel Value')
plt.title('Snake scanning')
plt.show()

# %%
import heapq
from collections import defaultdict

# %%
def encode(frequency):
    heap = [[weight, [symbol, '']] for symbol, weight in frequency.items()]
    heapq.heapify(heap)
    while len(heap) > 1:
        lo = heapq.heappop(heap)
        hi = heapq.heappop(heap)
        for pair in lo[1:]:
            pair[1] = '0' + pair[1]
        for pair in hi[1:]:
            pair[1] = '1' + pair[1]
        heapq.heappush(heap, [lo[0] + hi[0]] + lo[1:] + hi[1:])
    return sorted(heapq.heappop(heap)[1:], key=lambda p: (len(p[-1]), p))

# %%
def huffall(y):
    finli = map (lambda x: finlist[y*x:(x+1)*y], range (5600/y)) 
    huffcode = []
    lenhuff = []
    for sym in finli:
        frequency = defaultdict(int)
        for symbol in sym:
            frequency[symbol] += 1

        huff = encode(frequency)
        #print "Symbol".ljust(10) + "Weight".ljust(10) + "Huffman Code"
        for p in huff:
            x = str(p[1])
            ya = x.lstrip('0')
            lenyz = len(ya)
            #print  p[0] , str(frequency[p[0]]).ljust(10) , ya
            lenhuff.append(lenyz)
            huffcode.append(p[1])
        del frequency
    print 'process complete'
    print "The length of Huffcode", len(huffcode)
    cr = float(5600*16)/sum(lenhuff)
    print "The compression ratio for frame size", y, "is", cr

# %%
for i in range(5,30,5):
    huffall(i)
    print "_"*10
# Out:
# process complete
# The length of Huffcode 4948
# The compression ratio for frame size 5 is 10.6590530573
# __________
# process complete
# The length of Huffcode 4945
# The compression ratio for frame size 10 is 6.96192696193
# __________
# process complete
# The length of Huffcode 4943
# The compression ratio for frame size 15 is 5.85812356979
# __________
# process complete
# The length of Huffcode 4945
# The compression ratio for frame size 20 is 5.13938281519
# __________
# process complete
# The length of Huffcode 4941
# The compression ratio for frame size 25 is 4.59652182835
# __________

# %%
frequency = defaultdict(int)
for symbol in finlist:
    frequency[symbol] += 1

huff = encode(frequency)
#print "Symbol".ljust(10) + "Weight".ljust(10) + "Huffman Code"
huffcode = []
lenhuff = []
for p in huff:
    x = str(p[1])
    ya = x.lstrip('0')
    lenyz = len(ya)
    #print  p[0] , str(frequency[p[0]]).ljust(10) , ya
    lenhuff.append(lenyz)
    huffcode.append(p[1])
print "process complete"
# Out:
# process complete

# %%
len(huffcode)
# Out:
# 4939

# %%
cr = float(5600*16)/sum(lenhuff)
print "not in frame", cr
# Out:
# not in frame 1.54845845431
